# %%
# Import the data into Python environment as a Pandas DataFrame.

import pandas as pd
import numpy as np

df = pd.read_csv(r'C:\Users\patha\Downloads\rainfall1627650742214.csv')
df
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
# Check for missing values, if any and drop the corresponding rows

df.dropna(inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641 entries, 0 to 640
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   STATE_UT_NAME  641 non-null    object
#  1   DISTRICT       641 non-null    object
#  2   JAN            641 non-null    float64
#  3   FEB            641 non-null    float64
#  4   MAR            641 non-null    float64
#  5   APR            641 non-null    float64
#  6   MAY            641 non-null    float64
#  7   JUN            641 non-null    float64
#  8   JUL            641 non-null    float64
#  9   AUG            641 non-null    float64
#  10  SEP            641 non-null    float64
#  11  OCT            641 non-null    float64
#  12  NOV            641 non-null    float64
#  13  DEC            641 non-null    float64
#  14  ANNUAL         641 non-null    float64
#  15  Jan-Feb        641 non-null    float64
#  16  Mar-May        641 non-null    float64
# ...

# %%
# Find the district that gets the highest annual rainfall

#Using list comprehension to get the numerical columns
list1 = [col for col in df.columns if df[col].dtype in ['float', 'int64']]
df[list1].agg(['max'])
# Out:
#        JAN    FEB    MAR    APR    MAY     JUN     JUL     AUG    SEP    OCT  \
# max  144.5  229.6  367.9  554.4  733.7  1476.2  1820.9  1522.1  826.3  517.7
#
#        NOV    DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# max  475.1  297.7  7229.3    335.3   1256.5   5228.0   1048.5

# %%
# Display the top 5 states that get the highest annual rainfall.

df['ANNUAL'].nlargest(n=5)
# Out:
# 55     7229.3
# 47     6379.9
# 46     6166.1
# 12     4402.1
# 598    4306.0
# Name: ANNUAL, dtype: float64

# %%
# Drop the columns 'Jan-Feb', 'Mar-May', 'Jun-Sep', 'Oct-Dec'

df= df.drop(['Jan-Feb','Mar-May', 'Jun-Sep', 'Oct-Dec'],axis=1)
print(df)
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
# Display the state-wise mean rainfall for all the months using a pivot table.

import pandas as pd

# Grouping by state and district and calculating mean of ANNUAL
grouped_mean = df.groupby(['STATE_UT_NAME', 'DISTRICT'])['ANNUAL'].mean()

# Convert the result to a DataFrame and rename the column
grouped_mean = grouped_mean.reset_index()
grouped_mean.columns = ['STATE_UT_NAME', 'DISTRICT', 'annual_mean']

# View result
grouped_mean.head()
# Out:
#                  STATE_UT_NAME       DISTRICT  annual_mean
# 0  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN       2913.3
# 1  ANDAMAN And NICOBAR ISLANDS        NICOBAR       2805.2
# 2  ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN       3015.7
# 3               ANDHRA PRADESH       ADILABAD       1120.0
# 4               ANDHRA PRADESH      ANANTAPUR        572.7

# %%
pivot1 = pd.pivot_table(df, index = 'ANNUAL', aggfunc=np.mean)
pivot1
# Out:
# C:\Users\patha\AppData\Local\Temp\ipykernel_133104\3902867672.py:1: FutureWarning: The provided callable <function mean at 0x000001D9F8948D60> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot1 = pd.pivot_table(df, index = 'ANNUAL', aggfunc=np.mean)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\patha\miniconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1943, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1942 try:
# -> 1943     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1944 except Exception as err:
#
# File c:\Users\patha\miniconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
# ...

# %%
# Display the count of districts in each state.

district_count = df.groupby('STATE_UT_NAME')['DISTRICT'].nunique().reset_index()
district_count.columns = ['STATE_UT_NAME', 'district_count']
print(district_count)
# Out:
#                   STATE_UT_NAME  district_count
# 0   ANDAMAN And NICOBAR ISLANDS               3
# 1                ANDHRA PRADESH              23
# 2             ARUNACHAL PRADESH              16
# 3                         ASSAM              27
# 4                         BIHAR              38
# 5                    CHANDIGARH               1
# 6                    CHATISGARH              18
# 7            DADAR NAGAR HAVELI               1
# 8                 DAMAN AND DUI               2
# 9                         DELHI               9
# 10                          GOA               2
# 11                      GUJARAT              26
# 12                      HARYANA              21
# 13                     HIMACHAL              12
# 14            JAMMU AND KASHMIR              22
# 15                    JHARKHAND              24
# 16                    KARNATAKA              30
# 17                       KERALA              14
# 18                  LAKSHADWEEP               1
# ...

# %%
# For each state, display the district that gets the highest rainfall in May. 
# Also display the recorded rainfall.

# Find the district with the maximum May rainfall in each state
idx = df.groupby('STATE_UT_NAME')['MAY'].idxmax()

# Use .loc to get those rows
max_rainfall_may = df.loc[idx, ['STATE_UT_NAME', 'DISTRICT', 'MAY']].reset_index(drop=True)

# Rename column for clarity
max_rainfall_may.columns = ['STATE_UT_NAME', 'DISTRICT', 'max_may_rainfall']

# Display result
print(max_rainfall_may)
# Out:
#                   STATE_UT_NAME       DISTRICT  max_may_rainfall
# 0   ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN             374.4
# 1                ANDHRA PRADESH  VISAKHAPATNAM              96.6
# 2             ARUNACHAL PRADESH     PAPUM PARE             453.0
# 3                         ASSAM      KARIMGANJ             604.0
# 4                         BIHAR     KISHANGANJ             155.7
# 5                    CHANDIGARH     CHANDIGARH              30.1
# 6                    CHATISGARH         BASTAR              38.6
# 7            DADAR NAGAR HAVELI            DNH               7.4
# 8                 DAMAN AND DUI          DAMAN               7.4
# 9                         DELHI      NEW DELHI              19.3
# 10                          GOA      NORTH GOA              94.3
# 11                      GUJARAT          DANGS              12.5
# 12                      HARYANA      PANCHKULA              27.9
# ...
